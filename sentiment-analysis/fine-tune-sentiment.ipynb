# %%
import torch 
torch.cuda.is_available()
# Out:
# False

# %%
torch.mps.is_available()
# Out:
# True

# %%
# !pip install datasets transformers huggingface_hub
# Out:
# Requirement already satisfied: datasets in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (4.4.1)
# Requirement already satisfied: transformers in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (4.57.1)
# Requirement already satisfied: huggingface_hub in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (0.36.0)
# Requirement already satisfied: filelock in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (2.3.4)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: packaging in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from transformers) (2025.10.23)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.1)
# Requirement already satisfied: anyio in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/vinegi/Documents/MyProjects/AIML-playground/.venv/lib/python3.11/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !apt-get install git-lfs
# Out:
# zsh:1: command not found: apt-get

# %%
from datasets import load_dataset

# %%
imdb = load_dataset("imdb")
